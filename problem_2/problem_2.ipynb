# %%
import numpy as np
from scipy.stats import ks_2samp, anderson_ksamp
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('./final_momentum_data.csv')
momentum_difference=np.array(df['momentum_difference'])
momentum_difference=np.where(momentum_difference > 0, 1, 0)
df_origin=pd.read_csv('Wimbledon_featured_matches.csv')
df_origin['momentum_difference']=momentum_difference

# %%
def count_consecutive_elements_np(arr):
    if len(arr) == 0:
        return np.array([])

    counts = []
    current_count = 1

    for i in range(1, len(arr)):
        if arr[i] == arr[i - 1]:
            current_count += 1
        else:
            counts.append(current_count)
            current_count = 1

    counts.append(current_count)  # 处理最后一个数的连续出现次数
    return np.array(counts)

# %%
np.random.seed(42)
sample1 = np.random.normal(loc=0, scale=1, size=100000)
sample2 = np.random.normal(loc=0, scale=1, size=300)

# K-S检验
def test_random(sample1,momentum_difference):
    
    ks_statistic, ks_p_value = ks_2samp(sample1, momentum_difference)
    print(f"K-S统计量: {ks_statistic}")
    print(f"K-S检验的p-value: {ks_p_value}")

    # Anderson-Darling检验
    ad_statistic, ad_critical_values, ad_significance_level = anderson_ksamp([sample1, momentum_difference])
    print(f"Anderson-Darling统计量: {ad_statistic}")
    print(f"Anderson-Darling检验的临界值: {ad_critical_values}")
    print(f"Anderson-Darling检验的显著性水平: {ad_significance_level}")

    # 根据检验结果进行解释
    alpha = 0.01  # 显著性水平
    print('----------------------------------------')
    if ks_p_value < alpha:
        print("拒绝原假设：两组数据不来自相同分布 (K-S检验)")
    else:
        print("接受原假设：两组数据来自相同分布 (K-S检验)")

    if ad_statistic > ad_critical_values[2]:
        print("拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)")
    else:
        print("接受原假设：两组数据来自相同分布 (Anderson-Darling检验)")
    print('----------------------------------------')

# %%
sample1 = np.random.normal(loc=0, scale=1, size=100000)
for i in df_origin['match_id'].unique():
    print('in match ',i)
    temp=df_origin[df_origin['match_id']==i]
    momentum_difference=np.array(temp['momentum_difference'])
    test_random(sample1=sample1,momentum_difference=momentum_difference)
# Out:
# in match  2023-wimbledon-1301
# K-S统计量: 0.49972
# K-S检验的p-value: 1.4558120605478684e-69
# Anderson-Darling统计量: 138.3749154241521
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1302
# K-S统计量: 0.49972
# K-S检验的p-value: 6.180383709340608e-47
# Anderson-Darling统计量: 57.564639035590574
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1303
# K-S统计量: 0.49972
# K-S检验的p-value: 1.8244646115665357e-31
# Anderson-Darling统计量: 39.51755825069059
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1304
# K-S统计量: 0.49972
# K-S检验的p-value: 4.167907127843354e-78
# Anderson-Darling统计量: 128.9284220350901
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1305
# K-S统计量: 0.49972
# K-S检验的p-value: 4.2809824586112657e-57
# Anderson-Darling统计量: 96.91320965895336
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1306
# K-S统计量: 0.49972
# K-S检验的p-value: 5.948435227498476e-77
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10176\4280929050.py:13: UserWarning: p-value floored: true value smaller than 0.001
#   ad_statistic, ad_critical_values, ad_significance_level = anderson_ksamp([sample1, momentum_difference])
# Anderson-Darling统计量: 150.79262949321657
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1307
# K-S统计量: 0.49972
# K-S检验的p-value: 7.313112071506096e-54
# Anderson-Darling统计量: 96.8795550918104
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1308
# K-S统计量: 0.49972
# K-S检验的p-value: 2.142319759352412e-44
# Anderson-Darling统计量: 55.94361637970142
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1309
# K-S统计量: 0.49972
# K-S检验的p-value: 1.0477311731680115e-49
# Anderson-Darling统计量: 78.83687775951051
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1310
# K-S统计量: 0.49972
# K-S检验的p-value: 1.0161551146696505e-73
# Anderson-Darling统计量: 123.32873738510813
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1311
# K-S统计量: 0.49972
# K-S检验的p-value: 8.888509275657426e-40
# Anderson-Darling统计量: 48.54790435008274
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1312
# K-S统计量: 0.49972
# K-S检验的p-value: 8.620449200200546e-64
# Anderson-Darling统计量: 96.18871204488245
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1313
# K-S统计量: 0.49972
# K-S检验的p-value: 2.9653438691757546e-67
# Anderson-Darling统计量: 117.95085202580431
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1314
# K-S统计量: 0.6093375675675676
# K-S检验的p-value: 1.8565605968106797e-66
# Anderson-Darling统计量: 136.87941856634234
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1315
# K-S统计量: 0.49972
# K-S检验的p-value: 3.045838716412878e-46
# Anderson-Darling统计量: 58.09214703225878
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1316
# K-S统计量: 0.49972
# K-S检验的p-value: 4.3804708521312807e-39
# Anderson-Darling统计量: 52.88446784670859
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1401
# K-S统计量: 0.49972
# K-S检验的p-value: 3.0226076200133065e-52
# Anderson-Darling统计量: 109.29175723568929
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1402
# K-S统计量: 0.49972
# K-S检验的p-value: 1.4669891294692923e-63
# Anderson-Darling统计量: 103.51502968132282
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1403
# K-S统计量: 0.49972
# K-S检验的p-value: 1.0762347875569259e-28
# Anderson-Darling统计量: 60.3072088706172
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1404
# K-S统计量: 0.49972
# K-S检验的p-value: 2.4869267432295197e-66
# Anderson-Darling统计量: 82.37785769628697
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1405
# K-S统计量: 0.49972
# K-S检验的p-value: 3.6178923783755587e-50
# Anderson-Darling统计量: 117.26536777780083
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1406
# K-S统计量: 0.49972
# K-S检验的p-value: 1.50106119280656e-45
# Anderson-Darling统计量: 87.55522099334073
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1407
# K-S统计量: 0.49972
# K-S检验的p-value: 1.012277723736461e-76
# Anderson-Darling统计量: 153.48709924701512
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1408
# K-S统计量: 0.49972
# K-S检验的p-value: 7.2296604378681e-63
# Anderson-Darling统计量: 81.40715842400446
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1501
# K-S统计量: 0.5031456613756614
# K-S检验的p-value: 8.275157458842472e-45
# Anderson-Darling统计量: 104.5574673637244
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1502
# K-S统计量: 0.49972
# K-S检验的p-value: 1.2256146740123234e-65
# Anderson-Darling统计量: 135.63798306883996
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1503
# K-S统计量: 0.49972
# K-S检验的p-value: 4.3470310731458115e-45
# Anderson-Darling统计量: 95.77577721390166
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1504
# K-S统计量: 0.49972
# K-S检验的p-value: 1.2492847323977544e-50
# Anderson-Darling统计量: 66.83785173787705
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1601
# K-S统计量: 0.5398832075471698
# K-S检验的p-value: 6.640856411606796e-44
# Anderson-Darling统计量: 97.18526547494095
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1602
# K-S统计量: 0.49972
# K-S检验的p-value: 3.6317696177855284e-47
# Anderson-Darling统计量: 58.235776675703946
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
# in match  2023-wimbledon-1701
# K-S统计量: 0.49972
# K-S检验的p-value: 2.05403979448852e-77
# Anderson-Darling统计量: 121.40116096166636
# Anderson-Darling检验的临界值: [0.325 1.226 1.961 2.718 3.752 4.592 6.546]
# Anderson-Darling检验的显著性水平: 0.001
# ----------------------------------------
# 拒绝原假设：两组数据不来自相同分布 (K-S检验)
# 拒绝原假设：两组数据不来自相同分布 (Anderson-Darling检验)
# ----------------------------------------
